# %% [markdown]
# ## Data Visualization Notes

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 10,100)

# %%
plt.plot(x, np.sin(x),'-')
plt.plot(x, np.cos(x), '--')

plt.xlabel('x ekseni')
plt.ylabel('y ekseni')
plt.legend(("sin", "cos"));

# %%
fig = plt.figure() # **********************
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x),'-')



plt.xlabel('x ekseni')
plt.ylabel('y ekseni')
plt.legend(("sin",))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), '--', linewidth = 4, color = "red")


plt.xlabel('x ekseni')
plt.ylabel('y ekseni')
plt.legend(("cos"));

# %%
fig.savefig('figure.png') # *****************************

# %%
import seaborn as sns
import pandas as pd

# %%
iris = sns.load_dataset('iris')
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['petal_length'].plot();

# %%
sns.lineplot(data = iris, y = 'sepal_width', x = iris.index, hue = 'species');

# %% [markdown]
# ## Scatter plot uygulama

# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot

x = 20 * randn(1000) + 100
y = x + (10 * randn(1000) + 50)

pyplot.scatter(x, y)
pyplot.show()

# %%
#OVERPLOTTING 
fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(iris['sepal_length'], iris['sepal_width']);
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# ## Bar plot

# %%
iris.groupby(by = 'species').mean()['sepal_length'] # max()/min()/total()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
data = iris.groupby(by = 'species').mean()['sepal_length']
ax = sns.barplot(x=data.index, y=data.values)
ax.set_title('Sepal Lenght Means')
ax.set_ylabel('Max')
# Out:
# Text(0, 0.5, 'Max')

# %% [markdown]
# ## Histogram (bar sayısı formülü yararlı olabilir 3.5xStd/ 3kök(n))

# %%
sns.histplot(data=iris, x='sepal_width', hue = 'species');

# %%
sns.histplot(data=iris, x='sepal_width', bins=20);

# %%
sns.histplot(data=iris, x='sepal_width', bins=10);

# %%
sns.histplot(data=iris, x='sepal_width', bins=30); # bazı aralıklarda değer yok

# %% [markdown]
# ## Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array ([35,25,25,15])
labels = ["Elma", "Armut", "Üzüm", "Mango"]
plt.pie(y,labels = labels)
plt.show()

# %% [markdown]
# ## Heatmap

# %%
import numpy as np

# %%
np.random.seed(0)
uniform_data = np.random.rand(10,12)

ax = sns.heatmap(uniform_data)

# %%
iris.corr() #korelasyonlar
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot = True);

# %% [markdown]
# ## Box Plot

# %%
tips = sns.load_dataset("tips")
tips.head()
tips.describe().T
sns.boxplot(x = tips["total_bill"]);

# %%
sns.boxplot(data = iris, y ='sepal_length', x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>
